# %% [markdown]
# Iris flower classification

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# %% [markdown]
# <li>Pandas: pandas is used for managing the dataset or we can say read and manipulate the data</li>
# <li>Numpy: numpy is used for handaling arrays or performing mathematical computation</li>
# <li>Matplotlib: matplotlib is used to crate static visulaization like line graph scatter plot</li>
# <li>Seaborn: seaborn is used to provide higher level interface for creating visually appealing graphs</li>

# %%
columns=['Sepal-length','Sepal-width','Petal-length','Petal-width','Class-label']
df=pd.read_csv("iris.data.csv",names=columns)
# read csv and provide columnn names

# %%
# first 5 of dataset
df.head()
# Out:
#    Sepal-length  Sepal-width  Petal-length  Petal-width  Class-label
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
# last five of dataset
df.tail()
# Out:
#      Sepal-length  Sepal-width  Petal-length  Petal-width     Class-label
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %%
# give count of columns and rows to check whether the data is full
df.count()
# Out:
# Sepal-length    150
# Sepal-width     150
# Petal-length    150
# Petal-width     150
# Class-label     150
# dtype: int64

# %%
# some basics analytics of data 
df.describe()
# Out:
#        Sepal-length  Sepal-width  Petal-length  Petal-width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# visualizing the data
sns.pairplot(df,hue='Class-label')

# %% [markdown]
# Note:<br>
# <li>Seeing this graph we can clearly say that Iris-setosa is well seprated from other two flower</li>
# <li>Also we can say that Iris-virginca is the longest and Iris-setosa is the smallest (from sepal length)</li>

# %%
# seprates features and values
data=df.values
x=data[:,0:4] 
#selects all rows of  first 4 columns of dataset i.e sepal-length,sepal-width,petal-length & petal-width.
y=data[:,4]
#select all rows of 5th column of dataset i.e: class-label

# %%
# splitting data into training and testing (20% for testing and 80% for training)
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
# random state is used to get random from data to avoid errors like if the data is sorted there is chance we train only

# %% [markdown]
# Using KNN

# %%
# initalizing the knn model by providing the n as 3
knn=KNeighborsClassifier(n_neighbors=3)
# training the model by providing data
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
# Predicting using testing data
y_pred=knn.predict(x_test)
#calculating the accuracy score by comparing the test data and predicted data
KNN_accuracy=accuracy_score(y_test,y_pred)
print("Accuracy: "+str(KNN_accuracy*100)+"%")
# Out:
# Accuracy: 100.0%

# %% [markdown]
# Using Decision tree

# %%
# DecisionTreeClassifier
tree=DecisionTreeClassifier()
# Training model using training data
tree.fit(x_train,y_train)
# Predicting data using model
y_pred=tree.predict(x_test)
# calculating accuracy by comparing test data and predicted data
tree_accuracy=accuracy_score(y_test,y_pred)
print("Accuracy: "+str(tree_accuracy*100)+"%")
# Out:
# Accuracy: 100.0%

# %% [markdown]
# Using SVM Support Vector Machine

# %%
# Support vector machine
svc=SVC()
# training the model using training data
svc.fit(x_train,y_train)
# predicitng values using svm model
svm_pred=svc.predict(x_test)
# calculating accuracy score by comparing test and predicited data
svm_accuracy=accuracy_score(y_test,y_pred)
print("Accuracy: "+str(svm_accuracy*100)+"%")
# Out:
# Accuracy: 100.0%

# %%
algo=["KNN","Decision Tree","SVM"]
accuracy_scores=[KNN_accuracy,tree_accuracy,svm_accuracy]
plt.title("Comparison of 3 Different models")
plt.xlabel("Algorithm")
plt.ylabel("Score")
plt.bar(algo,accuracy_scores,color=['blue','red','orange'])
plt.ylim(0,1)
plt.figure(figsize=(10,6))
plt.show()
